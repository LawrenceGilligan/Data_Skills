# %%
import pandas as pd
import plotly.graph_objects as go
import plotly.express as px
import plotly.io as pio

pio.templates.default = "plotly_dark"

# %%
df = pd.read_csv('PGA_RAW_DATA.csv')

# %%
df.head()
# Out:
#   Player_initial_last  tournament id  player id  hole_par  strokes  hole_DKP  \
# 0            A. Ancer      401353224       9261       288      289      60.0
# 1           A. Hadwin      401353224       5548       288      286      72.5
# 2           A. Lahiri      401353224       4989       144      147      21.5
# 3             A. Long      401353224       6015       144      151      20.5
# 4            A. Noren      401353224       3832       144      148      23.5
#
#    hole_FDP  hole_SDP  streak_DKP  streak_FDP  ...  purse  season  no_cut  \
# 0      51.1        56           3         7.6  ...   12.0    2022       0
# 1      61.5        61           8        13.0  ...   12.0    2022       0
# 2      17.4        27           0         0.0  ...   12.0    2022       0
# 3      13.6        17           0         0.4  ...   12.0    2022       0
# 4      18.1        23           0         1.2  ...   12.0    2022       0
#
# ...

# %%
stats_df = df[df['season'] == 2022]

# %%
stats_df.head(5)
# Out:
#    hole_par  strokes  hole_DKP  hole_FDP  hole_SDP  streak_DKP  streak_FDP  \
# 0       288      289      60.0      51.1        56           3         7.6
# 1       288      286      72.5      61.5        61           8        13.0
# 2       144      147      21.5      17.4        27           0         0.0
# 3       144      151      20.5      13.6        17           0         0.4
# 4       144      148      23.5      18.1        23           0         1.2
#
#    streak_SDP  n_rounds  made_cut  ...  \
# 0           3         4         1  ...
# 1           3         4         1  ...
# 2           0         2         0  ...
# 3           0         2         0  ...
# 4           0         2         0  ...
#
#                                      course        date  season  Finish  \
# 0  Muirfield Village Golf Club - Dublin, OH  2022-06-05    2022     T32
# 1  Muirfield Village Golf Club - Dublin, OH  2022-06-05    2022     T18
# ...

# %%
stats_2022_df = stats_df[['season', 'player', 'strokes', 'hole_par', 'course', 'tournament name']]

# %%
stats_2022_df.head()
# Out:
#    season           player  strokes  hole_par  \
# 0    2022    Abraham Ancer      289       288
# 1    2022      Adam Hadwin      286       288
# 2    2022   Anirban Lahiri      147       144
# 3    2022        Adam Long      151       144
# 4    2022  Alexander Noren      148       144
#
#                                      course  \
# 0  Muirfield Village Golf Club - Dublin, OH
# 1  Muirfield Village Golf Club - Dublin, OH
# 2  Muirfield Village Golf Club - Dublin, OH
# 3  Muirfield Village Golf Club - Dublin, OH
# 4  Muirfield Village Golf Club - Dublin, OH
#
#                                tournament name
# 0  The Memorial Tournament pres. by Nationwide
# 1  The Memorial Tournament pres. by Nationwide
# 2  The Memorial Tournament pres. by Nationwide
# 3  The Memorial Tournament pres. by Nationwide
# 4  The Memorial Tournament pres. by Nationwide

# %%
fig = px.scatter(stats_2022_df, x='hole_par', y='strokes', color= 'player', facet_col="course", facet_row="tournament name")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8828\2332163839.py in <module>
# ----> 1 fig = px.scatter(stats_2022_df, x='hole_par', y='strokes', color= 'player', facet_col="course", facet_row="tournament name")
#
# ...
